# %%
import pandas as pd
import numpy as np

#importando as bibliotecas do Python

# %%
dados = pd.read_csv('atendimentofornecedor20202trimestre.csv', encoding='utf-8', sep=";")

# %%
dados.head()
# Out:
#    AnoAtendimento  TrimestreAtendimento  MesAtendimento  \
# 0            2020                     2               5
# 1            2020                     2               5
# 2            2020                     2               5
# 3            2020                     2               5
# 4            2020                     2               5
#
#            DataAtendimento  CodigoRegiao    Regiao  UF  CodigoTipoAtendimento  \
# 0  2020-05-13 09:27:36.000             2  Nordeste  PE                      6
# 1  2020-05-13 09:55:29.000             2  Nordeste  PE                      6
# 2  2020-05-19 11:36:11.000             2  Nordeste  PE                      6
# 3  2020-05-20 11:08:37.000             2  Nordeste  PE                      3
# 4  2020-05-20 11:32:17.000             2  Nordeste  PE                      7
#
#                   DescricaoTipoAtendimento  CodigoAssunto  ... CEPConsumidor  \
# 0                   Atendimento Preliminar            183  ...           NaN
# 1                   Atendimento Preliminar            183  ...    55026180.0
# 2                   Atendimento Preliminar            183  ...    55026260.0
# 3  CIP (Carta de Informações Preliminares)             54  ...           NaN
# 4            Encaminhamento a Fiscalização            103  ...           NaN
#
#   TipoFornecedor                                  RazaoSocialSindec  \
# 0              1     COMPESA - COMPANHIA PERNAMBUCANA DE SANEAMENTO
# 1              1     COMPESA - COMPANHIA PERNAMBUCANA DE SANEAMENTO
# 2              1     COMPESA - COMPANHIA PERNAMBUCANA DE SANEAMENTO
# 3              1  CRED-SYSTEM ADMINISTRADORA CARTÕES DE CREDITO ...
# 4              1                                  SKINÃO DOS BALDES
#
#                                   NomeFantasiaSindec      CNPJ RadicalCNPJ  \
# 0  DIRETORIA COMERCIAL E DE ATENDIMENTO - END. ÚNICO  9,77E+12   9769035.0
# 1  DIRETORIA COMERCIAL E DE ATENDIMENTO - END. ÚNICO  9,77E+12   9769035.0
# 2  DIRETORIA COMERCIAL E DE ATENDIMENTO - END. ÚNICO  9,77E+12   9769035.0
# 3                                         CREDSYSTEM  4,67E+12   4670195.0
# 4                                                NaN       NaN         NaN
#
#                                       RazaoSocialRFB  NomeFantasiaRFB  \
# 0               COMPANHIA PERNAMBUCANA DE SANEAMENTO          COMPESA
# 1               COMPANHIA PERNAMBUCANA DE SANEAMENTO          COMPESA
# 2               COMPANHIA PERNAMBUCANA DE SANEAMENTO          COMPESA
# 3  CRED - SYSTEM ADMINISTRADORA DE CARTOES DE CRE...              NaN
# 4                                                NaN              NaN
#
#    CodigoCNAEPrincipal                       DescricaoCNAEPrincipal
# 0            3600601.0  CAPTAÇÃO, TRATAMENTO E DISTRIBUIÇÃO DE ÁGUA
# 1            3600601.0  CAPTAÇÃO, TRATAMENTO E DISTRIBUIÇÃO DE ÁGUA
# 2            3600601.0  CAPTAÇÃO, TRATAMENTO E DISTRIBUIÇÃO DE ÁGUA
# 3            6613400.0          ADMINISTRAÇÃO DE CARTÕES DE CRÉDITO
# 4                  NaN                                          NaN
#
# [5 rows x 27 columns]

# %%
dados.shape
# Verificando meu número de linhas e colunas (inicial)
# Out:
# (344890, 27)

# %%
dados.columns 
# Verificando as colunas existentes dentro do meu dataset
# Out:
# Index(['AnoAtendimento', 'TrimestreAtendimento', 'MesAtendimento',
#        'DataAtendimento', 'CodigoRegiao', 'Regiao', 'UF',
#        'CodigoTipoAtendimento', 'DescricaoTipoAtendimento', 'CodigoAssunto',
#        'DescricaoAssunto', 'GrupoAssunto', 'CodigoProblema',
#        'DescricaoProblema', 'GrupoProblema', 'SexoConsumidor',
#        'FaixaEtariaConsumidor', 'CEPConsumidor', 'TipoFornecedor',
#        'RazaoSocialSindec', 'NomeFantasiaSindec', 'CNPJ', 'RadicalCNPJ',
#        'RazaoSocialRFB', 'NomeFantasiaRFB', 'CodigoCNAEPrincipal',
#        'DescricaoCNAEPrincipal'],
#       dtype='object')

# %%
dados.dtypes

# Verificando os tipo de dados presentes em cada coluna
# Out:
# AnoAtendimento                int64
# TrimestreAtendimento          int64
# MesAtendimento                int64
# DataAtendimento              object
# CodigoRegiao                  int64
# Regiao                       object
# UF                           object
# CodigoTipoAtendimento         int64
# DescricaoTipoAtendimento     object
# CodigoAssunto                 int64
# DescricaoAssunto             object
# GrupoAssunto                 object
# CodigoProblema                int64
# DescricaoProblema            object
# GrupoProblema                object
# SexoConsumidor               object
# FaixaEtariaConsumidor        object
# CEPConsumidor               float64
# TipoFornecedor                int64
# RazaoSocialSindec            object
# NomeFantasiaSindec           object
# CNPJ                         object
# RadicalCNPJ                 float64
# RazaoSocialRFB               object
# NomeFantasiaRFB              object
# CodigoCNAEPrincipal         float64
# DescricaoCNAEPrincipal       object
# dtype: object

# %%
#dropando colunas que não serão utlizadas na analise

dados2 = dados.drop(columns=["AnoAtendimento","TrimestreAtendimento","DataAtendimento","CodigoRegiao","CodigoTipoAtendimento","CodigoAssunto","DescricaoAssunto",                           
"CodigoProblema","DescricaoProblema","CEPConsumidor","TipoFornecedor","RazaoSocialSindec","NomeFantasiaSindec","CNPJ","RadicalCNPJ","CodigoCNAEPrincipal","DescricaoCNAEPrincipal","RazaoSocialRFB"])

# %%
dados2.isnull().sum()

#realizando  a soma de valores nulos, verifica-se que NomeFantasiaRFB possui 206212, valores nulos / NA
# Out:
# MesAtendimento                   0
# Regiao                           0
# UF                               0
# DescricaoTipoAtendimento         0
# GrupoAssunto                     0
# GrupoProblema                    0
# SexoConsumidor                   0
# FaixaEtariaConsumidor            0
# NomeFantasiaRFB             206212
# dtype: int64

# %%
dados2.dropna(inplace=True)


#dropando e realizando essa alteração dentro do dataset

# %%
dados2.isnull().sum()

#confirmando a existencia de valores nulos
# Out:
# MesAtendimento              0
# Regiao                      0
# UF                          0
# DescricaoTipoAtendimento    0
# GrupoAssunto                0
# GrupoProblema               0
# SexoConsumidor              0
# FaixaEtariaConsumidor       0
# NomeFantasiaRFB             0
# dtype: int64

# %%
dados2.shape

#visualizando as novas dimensões do conjunto de dados
# Out:
# (138678, 9)

# %%
dados2.head()
# Out:
#    MesAtendimento    Regiao  UF DescricaoTipoAtendimento      GrupoAssunto  \
# 0               5  Nordeste  PE   Atendimento Preliminar     Água / Esgoto
# 1               5  Nordeste  PE   Atendimento Preliminar     Água / Esgoto
# 2               5  Nordeste  PE   Atendimento Preliminar     Água / Esgoto
# 5               5  Nordeste  PE   Atendimento Preliminar  Energia Elétrica
# 6               5  Nordeste  PE   Atendimento Preliminar     Água / Esgoto
#
#             GrupoProblema SexoConsumidor FaixaEtariaConsumidor NomeFantasiaRFB
# 0       Problemas com SAC              F         Nao Informada         COMPESA
# 1       Problemas com SAC              F    entre 51 a 60 anos         COMPESA
# 2       Problemas com SAC              F    entre 41 a 50 anos         COMPESA
# 5  Problemas com Contrato              F         Nao Informada           CELPE
# 6  Problemas com Cobrança              F    entre 51 a 60 anos         COMPESA

# %%
dados2["MesAtendimento"].unique()

#únicos valores presentes na coluna MesAtendimento
# Out:
# array([5, 6, 4], dtype=int64)

# %%
dados2["UF"].unique()

#únicos valores presentes na coluna UF
# Out:
# array(['PE', 'AL', 'SE', 'BA', 'MG', 'SP', 'RO', 'AC', 'AM', 'PA', 'AP',
#        'TO', 'PR', 'MA', 'ES', 'PI', 'CE', 'RN', 'PB', 'SC', 'RJ', 'RS',
#        'MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
dados2["DescricaoTipoAtendimento"].unique()

#únicos valores presentes na coluna DescricaoTipoAtendimento
# Out:
# array(['Atendimento Preliminar',
#        'CIP (Carta de Informações Preliminares)', 'Simples Consulta',
#        'Abertura Direta de Reclamação', 'Encaminhamento a Fiscalização',
#        'Reclamação de Ofício', 'Cálculo', 'Inicial JEC'], dtype=object)

# %%
dados2["GrupoAssunto"].unique()

#único valores presentes na coluna GrupoAssunto
# Out:
# array(['Água / Esgoto', 'Energia Elétrica', 'Serviços de Vidraçaria',
#        'Financeira', 'Aparelho Celular', 'Transportes',
#        'Internet (Serviços e Produtos)', 'Telefonia Fixa',
#        'TV por Assinatura', 'Banco comercial', 'Cartão de Crédito',
#        'Telefonia Celular', 'Cartão de Loja', 'Serviços Postais',
#        'Banco de Dados e Cadastros de Consumidores (SPC, Serasa, SCPC etc.)',
#        'Empresa Privada / Montepio Pecúlio (Não Relativos ao Valor de Resgate)',
#        'Eletrodomésticos Linha Branca',
#        'Televisão / Aparelho DVD / Filmadora',
#        'Estabelecimento comercial (supermercado, loja, padaria, locadora, frutaria, etc.)',
#        'Microcomputador / Produtos de Informática',
#        'Artigos de Enxoval ( Cama / Mesa e Banho )',
#        'Telefonia Comunitária ( PABX, DDR, Etc. )',
#        'Plano de Assistência Funerária',
#        'Consultoria / Assessoria / Agenciamento ( Recolocação Profissional, Agência de Empregada, de Casamento, Etc. )',
#        'Contratos Financeiros Diversos*', 'Seguros (exceto Saúde)',
#        'Carros', 'Cursos Livres Outros',
#        'Agências e Operadoras de viagens (pacotes turísticos)',
#        'Outros Produtos Importados', 'Brinquedos',
#        'Escola ( Pré, 1º, 2º Graus e Superior )', 'Colchão',
#        'Academia de Ginástica / Natação / Esportes',
#        'Intercâmbio Cultural', 'Doces prontos',
#        'Produtos Doméstico ( Escada, Balança, Overloque, Máquina de Costura / Tricô, Vassoura, Escova, Rodo, Saco de Lixo, Palha de Aço )',
#        'Artigo de Cozinha ( Coifa, Exaustor, Panela, Talher, Filtro de Café, Porta-Filtro, Louças, Etc. )',
#        'Plano de Saúde (Médico / Odontológico)',
#        'Aquecedor / Ventilador / Ar Condicionado / Circulador de Ar',
#        'Máquinas e Equipamentos',
#        'Hospital / Pronto Socorro / Ambulatório / Clínica Médica',
#        'Assistência Técnica', 'Leasing', 'Eletroeletrônico Importado',
#        'Consórcios', 'Eletrodoméstico Importado',
#        'Eletroportáteis ( Batedeira, Liqüidificador, Espremedor de Frutas, Etc. )',
#        'Material de Acabamento de Construção Pronto (Portão, Azulejos, Tintas, Pisos Para Revestimento, Paviflex )',
#        'Móveis', 'Artigo de audiovisual (CD, DVD etc.)',
#        'Acessório para Aparelho Eletrônico/Pilha/Elétrico (Agulha, fone de ouvido, bateria, etc.)',
#        'Produto de Uso Pessoal ( Barbeador, Depilador, Secador, Outros )',
#        'Produto Para Uso Veterinário ( Medicamento / Sabonete / Shampoo )',
#        'Vestuário (Calçados / Roupas / Acessórios)',
#        'Informações sobre o Procon*\t',
#        'Artigo Esportivo / Lazer ( Bola, Raquete, Rede, Cotoveleira, Arma, Baralho, Roleta, Etc. )',
#        'Acessório Para Veículo ( Alarme, Amortecedor, Câmbio, Buzina, Estofamento, Lâmpada, Bateria, etc.)',
#        'Empresa de Cobrança', 'Venda Programada',
#        'Aparelho Corretivo ( Ortopédico / Auditivo / Prótese / Acessório )',
#        'Cartões de Descontos', 'Farmácia / Drogaria',
#        'Produtos de Saúde ( Preservativo / Gaze / Esparadrapo / Curativo Adesivo / Agulha / Seringa / Termômetro / Inalador / Cotonetes )',
#        'Venda de alimentos pela Internet', 'Botijão de Gás',
#        'Diversão / Lazer / Cultura ( Teatro, Cinema, Casa Noturna, Etc. )',
#        'Supermercado', 'Artigo de Leitura (Jornal, Revista, Livros etc.)',
#        'Eventos ( Festas, Buffet, Formatura, Etc. )',
#        'Incorporação ( Construtoras e Incorporadoras )',
#        'Material de Escritório / Material Escolar',
#        'Curso de Informática', 'Óticas ( Lentes / Óculos )', 'Motos',
#        'Estabelecimento / Loja - Compra a Prazo',
#        'Produto de Higiene ( Absorvente / Fralda / Lenço de Papel Umedecidos / Papel Higiênico Perfumado / Sabonete / Shampoo / Condicionador / Creme e Escova Dental /',
#        'Cosméticos', 'Ovos',
#        'Material de Construção (areia, cimento, tijolo, pregos, lajes, blocos, etc.)',
#        'Artigo e Instrumento Musical ( Cordas, Violão, Flautas, Etc. )',
#        'Aparelho de Som',
#        'Artigo de Foto Imagem ( Filme, Ampliador, Luneta, Flash, Máquina Fotográfica, Binóculos, Etc. )',
#        'Automóvel - Locação / Assistência Automobilística ( Clube do Automóvel, Etc. ) / Auto Escola',
#        'Construção / Reforma / Montagem / Acabamento',
#        'Ferramenta ( Alicate, Cortador de Grama, Furadeira, Pá, Pincel, Etc. )',
#        'Estética ( Clínica de Emagrecimento / Plástica / Implante de Cabelos / Salão de Beleza )',
#        'Alimentos vendidos em Bares, Docerias, Chopperias, Casas Noturnas e Afins',
#        'Produto Químico ( Acetona / Creolina / Querosene / Cloro Puro - Para Piscinas )',
#        'Curso de Línguas', 'Carnes e Derivados',
#        'Oficinas ( Mecânica, Funilaria, Auto-Elétrica, Borracharia )',
#        'Hospedagem ( Hotel, Pousada, Chalé, Albergue, Etc. )',
#        'Loteamento', 'Foto / Vídeo / Som', 'Mudanças',
#        'Combustível Automotivo ( Gasolina, Álcool, Diesel, Gás )',
#        'Artigo Para Festa ( Bexiga, Máscara, Enfeites, Fogos, Balão, Etc. )',
#        'Serviços de Serralheria ( Portão, Grades, Janelas, Etc. )',
#        'Café', 'Serviços Telefônicos Diversos', 'Bicicletas', 'Cemitério',
#        'Gás Encanado',
#        'Camping / Náutica / Pesca / ( Barraca, Lampião, Barco, Vela, Motor, Anzol, Vara, Jet Ski )',
#        'Cortina / Persiana / Papel de Parede', 'Serviços de Marcenaria',
#        'Locação (Habitação)',
#        'Clínica Geriátrica ( Casa de Repouso / Internato / Similares )',
#        'Clubes / Uso Compartilhado ( Lazer, Recreação, Férias, Etc. )',
#        'Pneu', 'Profissional Liberal - Dentista', 'Despachante',
#        'Ração animal', 'Condomínio',
#        'Estacionamento ( Particular, Supermercado, Shopping, Etc. )',
#        'Clínica Veterinária', 'Purificador de Água / Filtro',
#        'Grãos, cereais (feijão, grão de bico, arroz, farelo de trigo, sucrilho, aveia, granola, creme de arroz)',
#        'Instalação ( Hidráulica / Elétrica ) / Perfuração / Pavimentação / Impermeabilização',
#        'Profissional Liberal ( Contador, Arquiteto )',
#        'Outros Profissionais Liberais relacionados a Saúde ( Esteticista / Massagista / Farmacêutico )',
#        'Piscina ( Fibra ) / Sauna / Banheira de Hidromassagem',
#        'Titulo de Capitalização',
#        'Domissanitário / Saneante (Desinfetante / Detergente / Cera / Creolina / Sabão / Água Sanitária / Inseticida)',
#        'Medicamento Homeopático / Fitoterápico ( Manipulado / Industrializado )',
#        'Lavanderia / Tinturaria', 'Transporte Escolar',
#        'Venda a Domicílio / Reembolso Postal',
#        'Chocolate (em pó, barra, tabletes, bombons)',
#        'Açougue e Peixarias ( Produtos Crus Vendidos Neste Local )',
#        'Medicamento Alopático ( Manipulado / Industrializado )',
#        'Dedetizadora', 'Leite e derivados',
#        'Alimentos infantis (leites próprios para crianças, sopinha, etc)',
#        'Telemarketing', 'Complementos e suplementos nutricionais', 'Chá',
#        'Balança (informação nutricional, como valor calórico e relação peso/altura)',
#        'Profissional Liberal - Médico',
#        'Produtos de Saúde Comprados pela Internet', ' Não se aplica',
#        'Bebidas Alcoólicas',
#        'Conserva Animal (atum, sardinha, apresuntado, alite, feijoada, patê, etc.)',
#        'Alimentos para fins especiais (atletas, gestantes, idosos)',
#        'Padaria',
#        'Outros Serviços de Saúde ( Laboratório de Análises Clínicas / Clínicas Que Realizam Exames / Remoção )',
#        'Alimento dietético (exceto refrigerante dietético)',
#        'Convênio de Assistência Veterinária', 'Funerária',
#        'Temperos prontos', 'Água', 'Luminárias/lâmpadas',
#        'Venda por telemarketing', 'Frutas e hortaliças',
#        'Charutaria ( Cigarro, Tabaco, Cachimbo, Etc. )',
#        'Prestadora de Serviço de Reabilitação de Nome',
#        'Especiarias e Condimentos', 'Serviços de Tapeçaria / Costura',
#        'Tomate e derivados (in natura, extratos, molhos, polpa)',
#        'Massas', 'Leiloeiro',
#        'Restaurante / Fast Food ( Refeições / Sanduíches Servidos Pelo Local )',
#        'Artigos de Decoração', 'Carpete / Tapete ( Nylon, Madeira )',
#        'Alimentos nutraceuticos (alimentos com finalidade terapêutica)',
#        'Bolacha, biscoitos e petiscos',
#        'Pães e bolos industrializados (pão de forma, bisnagas, bolos)',
#        'Refrigerantes (normal, dietético e light)',
#        'Associações / Cooperativas / Sociedades Filantrópicas',
#        'Pratos prontos/pré preparados',
#        'Produtos alimentícios importados (todos os produtos)',
#        'Fermento em pó e o biológico',
#        'Sociedade em conta de participação', 'Comércio de Ouro',
#        'Peixes e frutos do mar (congelados e embalados)',
#        'Desentupidoras', 'Aparelhos de ginástica',
#        'Óleos e gorduras (margarina normal e light, gordura vegetal hidrogenada, etc.)',
#        'Açúcar / Mel', 'Plantas',
#        'Canil / Pet Shop / Outros Estabelecimentos Que Comercializam Animais',
#        'Conserva Vegetal (azeitona, ervilha, milho, palmito, aspargo, cogumelo) em qualquer tipo de embalagem.',
#        'Farináceos (fubá, polvilho, etc.)', 'Radiochamada / Pager',
#        'Fósforo', 'Feiras Itinerantes',
#        'Molhos (maionese, mostarda, ketchup, shoyo, inglês)'],
#       dtype=object)

# %%
dados2["GrupoProblema"].unique() 

#únicos valores presentes na coluna GrupoAssunto
# Out:
# array(['Problemas com SAC', 'Problemas com Contrato',
#        'Problemas com Cobrança', 'Problemas na Entrega de Produtos',
#        'Vício ou Má Qualidade de Produto ou Serviço',
#        'Risco à Saúde e Segurança / Acidente de Consumo',
#        'Problemas Diversos com Produtos e Serviços',
#        'Problemas com Desistência de Compra ou Contratação',
#        'Problemas com Entrega de Documentos ao Consumidor',
#        'Problemas na Oferta', 'Problemas com Garantia de Produtos',
#        'Negativação Indevida de Consumidor', ' Não se aplica'],
#       dtype=object)

# %%
dados2["FaixaEtariaConsumidor"].unique()

#únicos valores presentes na coluna FaixaEtariaConsumidor
# Out:
# array(['Nao Informada', 'entre 51 a 60 anos', 'entre 41 a 50 anos',
#        'entre 31 a 40 anos', 'entre 21 a 30 anos', 'entre 61 a 70 anos',
#        'mais de 70 anos', 'até 20 anos', 'Nao se aplica'], dtype=object)

# %%
dados2.loc[dados2.FaixaEtariaConsumidor == 'Nao Informada', ['FaixaEtariaConsumidor']] = pd.NA

# %%
dados2.loc[dados2.GrupoProblema == 'Não se aplica', ['GrupoProblema']] = pd.NA

# %%
dados2.isna().sum()
# Out:
# MesAtendimento                  0
# Regiao                          0
# UF                              0
# DescricaoTipoAtendimento        0
# GrupoAssunto                    0
# GrupoProblema                   0
# SexoConsumidor                  0
# FaixaEtariaConsumidor       23597
# NomeFantasiaRFB                 0
# dtype: int64

# %%
dados2.head(900)
# Out:
#       MesAtendimento    Regiao  UF                 DescricaoTipoAtendimento  \
# 0                  5  Nordeste  PE                   Atendimento Preliminar
# 1                  5  Nordeste  PE                   Atendimento Preliminar
# 2                  5  Nordeste  PE                   Atendimento Preliminar
# 5                  5  Nordeste  PE                   Atendimento Preliminar
# 6                  5  Nordeste  PE                   Atendimento Preliminar
# ...              ...       ...  ..                                      ...
# 1963               4  Nordeste  PE  CIP (Carta de Informações Preliminares)
# 1967               4  Nordeste  PE                     Reclamação de Ofício
# 1968               4  Nordeste  PE                     Reclamação de Ofício
# 1970               4  Nordeste  PE                     Reclamação de Ofício
# 1972               4  Nordeste  PE                     Reclamação de Ofício
#
#                                            GrupoAssunto  \
# 0                                         Água / Esgoto
# 1                                         Água / Esgoto
# 2                                         Água / Esgoto
# 5                                      Energia Elétrica
# 6                                         Água / Esgoto
# ...                                                 ...
# 1963                                   Energia Elétrica
# 1967  Estabelecimento comercial (supermercado, loja,...
# 1968  Estabelecimento comercial (supermercado, loja,...
# 1970  Estabelecimento comercial (supermercado, loja,...
# 1972  Estabelecimento comercial (supermercado, loja,...
#
#                                    GrupoProblema SexoConsumidor  \
# 0                              Problemas com SAC              F
# 1                              Problemas com SAC              F
# 2                              Problemas com SAC              F
# 5                         Problemas com Contrato              F
# 6                         Problemas com Cobrança              F
# ...                                          ...            ...
# 1963                      Problemas com Cobrança              M
# 1967  Problemas Diversos com Produtos e Serviços              N
# 1968  Problemas Diversos com Produtos e Serviços              N
# 1970  Problemas Diversos com Produtos e Serviços              N
# 1972  Problemas Diversos com Produtos e Serviços              N
#
#      FaixaEtariaConsumidor                               NomeFantasiaRFB
# 0                     <NA>                                       COMPESA
# 1       entre 51 a 60 anos                                       COMPESA
# 2       entre 41 a 50 anos                                       COMPESA
# 5                     <NA>                                         CELPE
# 6       entre 51 a 60 anos                                       COMPESA
# ...                    ...                                           ...
# 1963    entre 61 a 70 anos                                         CELPE
# 1967         Nao se aplica  LOTERIA NOSSA SENHORA DA CONCEICAO LTDA - ME
# 1968         Nao se aplica                         MISTER SORTE LOTERIAS
# 1970         Nao se aplica                                     ALO SORTE
# 1972         Nao se aplica                                   SORTE CERTA
#
# [900 rows x 9 columns]

# %%
dados2.replace([' Não se aplica','Nao Informada','Nao se aplica'], pd.NA, inplace = True)

# %%
dados2.isna().sum()
# Out:
# MesAtendimento                  0
# Regiao                          0
# UF                              0
# DescricaoTipoAtendimento        0
# GrupoAssunto                 2122
# GrupoProblema                1854
# SexoConsumidor                  0
# FaixaEtariaConsumidor       25095
# NomeFantasiaRFB                 0
# dtype: int64

# %%
dados2.dropna(inplace=True)

# %%
#realizando a alteração dentro do meu dataset
dados2.drop_duplicates(inplace = True)

# %%
#contagem de linhas apos 
dados2.shape
# Out:
# (61799, 9)

# %%
dados2.isna().sum()
# Out:
# MesAtendimento              0
# Regiao                      0
# UF                          0
# DescricaoTipoAtendimento    0
# GrupoAssunto                0
# GrupoProblema               0
# SexoConsumidor              0
# FaixaEtariaConsumidor       0
# NomeFantasiaRFB             0
# dtype: int64

# %%
dados2["MesAtendimento"] = dados2['MesAtendimento'].astype('object')

# %%
dados2.dtypes


#tipo dos nossos dados observa-se que não "object/strings"
# Out:
# MesAtendimento              object
# Regiao                      object
# UF                          object
# DescricaoTipoAtendimento    object
# GrupoAssunto                object
# GrupoProblema               object
# SexoConsumidor              object
# FaixaEtariaConsumidor       object
# NomeFantasiaRFB             object
# dtype: object

# %%
dados2.isna().sum()  #validação
# Out:
# MesAtendimento              0
# Regiao                      0
# UF                          0
# DescricaoTipoAtendimento    0
# GrupoAssunto                0
# GrupoProblema               0
# SexoConsumidor              0
# FaixaEtariaConsumidor       0
# NomeFantasiaRFB             0
# dtype: int64

# %%
dados2["MesAtendimento"].value_counts(ascending=False)
# Out:
# 6    26680
# 5    22058
# 4    13061
# Name: MesAtendimento, dtype: int64

# %%
dados2["GrupoAssunto"].value_counts(ascending=True)
# Out:
# Alimentos infantis (leites próprios para crianças, sopinha, etc)       1
# Convênio de Assistência Veterinária                                    1
# Clínica Geriátrica ( Casa de Repouso / Internato / Similares )         1
# Plantas                                                                1
# Sociedade em conta de participação                                     1
#                                                                     ...
# Telefonia Fixa                                                      3200
# Contratos Financeiros Diversos*                                     3728
# Cartão de Crédito                                                   4063
# Banco comercial                                                     4091
# Telefonia Celular                                                   4521
# Name: GrupoAssunto, Length: 175, dtype: int64

# %%
dados2["MesAtendimento"].value_counts(ascending=False).plot.bar()

# 4 = Mês de Abril de 2020
# 5 = Mês de Maio  de 2020
# 6 = Mês de Junho de 2020
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

dados2["Regiao"].value_counts(ascending=False).plot.bar(title="Total de atendimentos por região", color="orange")
plt.xlabel("Regiões")
plt.ylabel("Número de atendimentos")
# Out:
# Text(0, 0.5, 'Número de atendimentos')

# %%
#contagem distinta, iremos selecionar para nosso gráfico apenas as 11 maiores ocorrências

dados2["UF"].value_counts(ascending=False)
# Out:
# SP    22809
# SC     6954
# GO     5388
# MG     4799
# PR     3738
# MT     2669
# ES     2195
# MS     2193
# MA     1751
# RS     1613
# TO     1506
# DF     1353
# RJ      834
# PE      721
# PB      661
# PA      635
# CE      489
# PI      381
# RO      345
# AL      318
# AM      223
# SE       92
# RN       71
# BA       54
# AP        6
# AC        1
# Name: UF, dtype: int64

# %% [raw]
# DADOS3= dados2.loc[dados2['UF'] == 'MA'] #gostaria de selecionar os 11 estados com o maior número de ocorrencias mas ao colocar mais estados apresenta erro
#
# DADOS3.head()
#
# #SEGREGANDO OS ESTADOS COM MAIOR NÚMERO DE ATENDIMENTOS (filtro1) E ESTADOS COM MENOR QUANTIDADE DE ATENDIMENTOS(filtro2)

# %% [raw]
# filtro2 = dados2.UF.isin(['DF','RJ','PE','PB', 'PA','CE','PI','RO','AL','AM','SE','RN','BA','AP','AC'])
# dfestados2 = dados2.loc[filtro2]
# #menor número de atendimentos

# %% [raw]
# filtro = dados2.UF.isin(['SP','SC','GO','MG','PR','MT','ES','MS', 'MA','RS','TO'])
# dfestados = dados2.loc[filtro]

# %%
dados2['UF'].replace('DF','Outros', inplace=True) 
dados2['UF'].replace('RJ','Outros',inplace=True)
dados2['UF'].replace('PE','Outros',inplace=True)
dados2['UF'].replace('PB','Outros',inplace=True)
dados2['UF'].replace('PA','Outros',inplace=True)
dados2['UF'].replace('CE','Outros',inplace=True)
dados2['UF'].replace('PI','Outros',inplace=True)
dados2['UF'].replace('RO','Outros',inplace=True)
dados2['UF'].replace('AL','Outros',inplace=True)
dados2['UF'].replace('AM','Outros',inplace=True)
dados2['UF'].replace('SE','Outros',inplace=True)
dados2['UF'].replace('RN','Outros',inplace=True)
dados2['UF'].replace('BA','Outros', inplace=True)
dados2['UF'].replace('AP','Outros',inplace=True)
dados2['UF'].replace('AC','Outros',inplace=True)

# %%
dados2["UF"].value_counts(ascending=False).plot.bar(title="Total de atendimentos por Estado", color="green")
plt.xlabel("Estados")
plt.ylabel("Número de atendimentos")
# Out:
# Text(0, 0.5, 'Número de atendimentos')

# %%
dados2["DescricaoTipoAtendimento"].value_counts(ascending=False).plot.bar(title="Total de atendimentos por tipo", color="black")
plt.xlabel("Tipos de atendimento")
plt.ylabel("Número de atendimentos")
# Out:
# Text(0, 0.5, 'Número de atendimentos')

# %%
#Faixa etária que mais abre chamados de reclamação
import pylab
pylab.rcParams['figure.figsize'] = (15.0, 8.0)
dados2["FaixaEtariaConsumidor"].value_counts(ascending=False).plot(marker = "o")
plt.xlabel("Tipos de atendimento")
# Out:
# Text(0.5, 0, 'Tipos de atendimento')

# %%
dados2["GrupoAssunto"].value_counts(ascending=False).plot.pie(title="Quantidade de reclamações por seguimento ")


#Vizualização comprometida, como deixar o top 10 e transformar o restante em "outros" ?
# Out:
# <AxesSubplot:title={'center':'Quantidade de reclamações por seguimento '}, ylabel='GrupoAssunto'>
# C:\Users\jhona\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jhona\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
dados2["GrupoProblema"].value_counts(ascending=False).plot.pie(title="Total de atendimentos por assunto")

#Vizualização comprometida, como deixar o top 5 e transformar o restante em "outros" ? 

#Problemas com cobrança, problemas com contrato, problemas com SAC, Vício ou má qualidade e problemas na entrega de produtos dominam a lista.
# Out:
# <AxesSubplot:title={'center':'Total de atendimentos por assunto'}, ylabel='GrupoProblema'>

# %%
dados2["NomeFantasiaRFB"].value_counts(ascending=False).plot.pie(title="Empresas com maior numero de reclamações")

#Vizualização comprometida, como deixar o top 5 e transformar o restante em "outros" ?
# Out:
# <AxesSubplot:title={'center':'Empresas com maior numero de reclamações'}, ylabel='NomeFantasiaRFB'>
# C:\Users\jhona\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\jhona\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26 missing from current font.
#   font.set_text(s, 0, flags=flags)
